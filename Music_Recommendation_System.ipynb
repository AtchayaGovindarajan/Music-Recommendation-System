# %% [markdown]
# <a href="https://colab.research.google.com/github/AtchayaGovindarajan/Music-Recommendation-System/blob/main/Music_Recommendation_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

def initialize_user_names(n):
    return [f'User_{i}' for i in range(1, n + 1)]

def initialize_tamil_song_names(n):
    tamil_movie_songs = [
        'Endhira Logathu Sundariye', 'Vaseegara', 'Ninaithu Ninaithu Parthen', 'Kadhal Anukkal',
        'Munbe Vaa', 'Vennilave', 'Ennavale Adi Ennavale', 'Pachai Nirame', 'Oru Deivam Thantha Poove',
        'Uyire Uyire', 'Kannukkul Nilavu', 'Snehithane Snehithane', 'Enna Solla Pogirai', 'Anbe Anbe Kollathey',
        'Mazhai Thuli Mannil', 'Poongatrile Un Swasathai', 'Thendral Vanthu Theendum Pothu', 'Ithu Kaadhal Kaadhal Kaatchi',
        'Azhagiya Theeye', 'Kannamoochi Yenada', 'Ennai Thalatta Varuvala', 'Mannipaaya', 'Neethane Neethane'
    ]
    return [f'{random.choice(tamil_movie_songs)}' for _ in range(n)]

def assign_genre(song_name):
    # Customized genre assignment for Tamil songs based on keywords
    keywords_and_genres = {
        'Melody': ['Vaseegara', 'Munbe Vaa', 'Snehithane Snehithane', 'Mannipaaya', 'Neethane Neethane'],
        'Folk': ['Kannamoochi Yenada', 'Azhagiya Theeye'],
        'Sad': ['Mazhai Thuli Mannil', 'Ennai Thalatta Varuvala'],
        'Pop': ['Endhira Logathu Sundariye', 'Kadhal Anukkal', 'Oru Deivam Thantha Poove'],
        'Rock': ['Kannukkul Nilavu', 'Ithu Kaadhal Kaadhal Kaatchi'],
        'R&B': ['Anbe Anbe Kollathey', 'Mannipaaya'],
        'Other': ['Ninaithu Ninaithu Parthen', 'Ennavale Adi Ennavale', 'Enna Solla Pogirai', 'Thendral Vanthu Theendum Pothu']
    }

    for genre, keywords in keywords_and_genres.items():
        if any(keyword in song_name for keyword in keywords):
            return genre

    # If no specific keyword is found, assign a random genre
    genres = list(keywords_and_genres.keys())
    return random.choice(genres)

def recommend_songs_and_most_played(df, user_id, num_recommendations=5):
    user_data = df[df['user_id'] == user_id]

    # Recommend songs for the user based on their favorite genre
    favorite_genre = user_data['genre'].mode().iloc[0]
    recommended_songs = df[df['genre'] == favorite_genre]['song_name'].unique()
    recommended_songs = random.sample(list(recommended_songs), min(num_recommendations, len(recommended_songs)))

    # Find the most played song in each genre for the user
    genre_counter = Counter(user_data['genre'])
    most_played_per_genre = {genre: user_data[user_data['genre'] == genre]['song_name'].mode().iloc[0] for genre in genre_counter}

    return recommended_songs, most_played_per_genre

# Generate 50 data points with initialization
num_data_points = 50

data = {
    'user_id': list(range(1, num_data_points + 1)),
    'user_name': initialize_user_names(num_data_points),
    'song_name': initialize_tamil_song_names(num_data_points),
    'genre': [assign_genre(song) for song in initialize_tamil_song_names(num_data_points)],
}

df = pd.DataFrame(data)
df.to_csv('/content/tamil_movie_songs_data.csv', index=False)
print(df)

# Recommend songs and find most played songs for all users
all_user_recommendations = {}

for user_id in df['user_id'].unique():
    recommended_songs, most_played_per_genre = recommend_songs_and_most_played(df, user_id)
    all_user_recommendations[user_id] = {'recommended_songs': recommended_songs, 'most_played_per_genre': most_played_per_genre}

# Print recommendations for all users
for user_id, recommendations in all_user_recommendations.items():
    print(f"\nUser {user_id}:")
    print(f"Recommended Songs: {recommendations['recommended_songs']}")
    print(f"Most Played Song per Genre: {recommendations['most_played_per_genre']}")
# Out:
#     user_id user_name                       song_name   genre
# 0         1    User_1       Endhira Logathu Sundariye    Folk
# 1         2    User_2           Ennavale Adi Ennavale  Melody
# 2         3    User_3              Kannamoochi Yenada   Other
# 3         4    User_4  Thendral Vanthu Theendum Pothu    Folk
# 4         5    User_5                      Mannipaaya  Melody
# 5         6    User_6                     Uyire Uyire  Melody
# 6         7    User_7                   Pachai Nirame  Melody
# 7         8    User_8                     Uyire Uyire     Pop
# 8         9    User_9                       Munbe Vaa     Sad
# 9        10   User_10                      Mannipaaya  Melody
# 10       11   User_11       Endhira Logathu Sundariye  Melody
# 11       12   User_12                 Azhagiya Theeye  Melody
# 12       13   User_13               Neethane Neethane  Melody
# 13       14   User_14                       Munbe Vaa     Pop
# 14       15   User_15              Kannamoochi Yenada     Pop
# 15       16   User_16           Snehithane Snehithane     Sad
# 16       17   User_17                   Pachai Nirame  Melody
# 17       18   User_18                       Munbe Vaa  Melody
# 18       19   User_19       Ninaithu Ninaithu Parthen     Pop
# 19       20   User_20       Endhira Logathu Sundariye     R&B
# 20       21   User_21       Ninaithu Ninaithu Parthen  Melody
# 21       22   User_22                  Kadhal Anukkal    Folk
# 22       23   User_23              Kannamoochi Yenada    Folk
# 23       24   User_24               Neethane Neethane     Sad
# 24       25   User_25    Ithu Kaadhal Kaadhal Kaatchi     Pop
# 25       26   User_26                   Pachai Nirame    Rock
# 26       27   User_27       Ninaithu Ninaithu Parthen   Other
# 27       28   User_28                       Munbe Vaa  Melody
# 28       29   User_29                  Kadhal Anukkal   Other
# 29       30   User_30        Oru Deivam Thantha Poove     Pop
# 30       31   User_31                 Azhagiya Theeye    Rock
# 31       32   User_32                Kannukkul Nilavu  Melody
# 32       33   User_33           Snehithane Snehithane     Sad
# 33       34   User_34        Poongatrile Un Swasathai   Other
# 34       35   User_35        Poongatrile Un Swasathai     Sad
# 35       36   User_36       Endhira Logathu Sundariye    Folk
# 36       37   User_37                Kannukkul Nilavu    Folk
# 37       38   User_38         Ennai Thalatta Varuvala    Rock
# 38       39   User_39                 Azhagiya Theeye  Melody
# 39       40   User_40               Neethane Neethane   Other
# 40       41   User_41             Anbe Anbe Kollathey   Other
# 41       42   User_42    Ithu Kaadhal Kaadhal Kaatchi     R&B
# 42       43   User_43                       Munbe Vaa     Sad
# 43       44   User_44             Anbe Anbe Kollathey   Other
# 44       45   User_45  Thendral Vanthu Theendum Pothu   Other
# 45       46   User_46              Enna Solla Pogirai   Other
# 46       47   User_47                       Munbe Vaa    Folk
# 47       48   User_48                  Kadhal Anukkal    Rock
# 48       49   User_49                Kannukkul Nilavu     R&B
# 49       50   User_50                   Pachai Nirame     Sad
#
# User 1:
# Recommended Songs: ['Thendral Vanthu Theendum Pothu', 'Kannamoochi Yenada', 'Kadhal Anukkal', 'Kannukkul Nilavu', 'Munbe Vaa']
# Most Played Song per Genre: {'Folk': 'Endhira Logathu Sundariye'}
#
# User 2:
# Recommended Songs: ['Endhira Logathu Sundariye', 'Uyire Uyire', 'Azhagiya Theeye', 'Ninaithu Ninaithu Parthen', 'Ennavale Adi Ennavale']
# Most Played Song per Genre: {'Melody': 'Ennavale Adi Ennavale'}
#
# User 3:
# Recommended Songs: ['Kadhal Anukkal', 'Enna Solla Pogirai', 'Thendral Vanthu Theendum Pothu', 'Poongatrile Un Swasathai', 'Kannamoochi Yenada']
# Most Played Song per Genre: {'Other': 'Kannamoochi Yenada'}
#
# User 4:
# Recommended Songs: ['Kannamoochi Yenada', 'Kannukkul Nilavu', 'Kadhal Anukkal', 'Munbe Vaa', 'Endhira Logathu Sundariye']
# Most Played Song per Genre: {'Folk': 'Thendral Vanthu Theendum Pothu'}
#
# User 5:
# Recommended Songs: ['Mannipaaya', 'Pachai Nirame', 'Neethane Neethane', 'Munbe Vaa', 'Ninaithu Ninaithu Parthen']
# Most Played Song per Genre: {'Melody': 'Mannipaaya'}
#
# User 6:
# Recommended Songs: ['Azhagiya Theeye', 'Uyire Uyire', 'Mannipaaya', 'Ninaithu Ninaithu Parthen', 'Ennavale Adi Ennavale']
# Most Played Song per Genre: {'Melody': 'Uyire Uyire'}
#
# User 7:
# Recommended Songs: ['Kannukkul Nilavu', 'Mannipaaya', 'Munbe Vaa', 'Azhagiya Theeye', 'Ninaithu Ninaithu Parthen']
# Most Played Song per Genre: {'Melody': 'Pachai Nirame'}
#
# User 8:
# Recommended Songs: ['Ithu Kaadhal Kaadhal Kaatchi', 'Uyire Uyire', 'Munbe Vaa', 'Oru Deivam Thantha Poove', 'Ninaithu Ninaithu Parthen']
# Most Played Song per Genre: {'Pop': 'Uyire Uyire'}
#
# User 9:
# Recommended Songs: ['Munbe Vaa', 'Poongatrile Un Swasathai', 'Neethane Neethane', 'Pachai Nirame', 'Snehithane Snehithane']
# Most Played Song per Genre: {'Sad': 'Munbe Vaa'}
#
# User 10:
# Recommended Songs: ['Pachai Nirame', 'Uyire Uyire', 'Ninaithu Ninaithu Parthen', 'Ennavale Adi Ennavale', 'Endhira Logathu Sundariye']
# Most Played Song per Genre: {'Melody': 'Mannipaaya'}
#
# User 11:
# Recommended Songs: ['Munbe Vaa', 'Ninaithu Ninaithu Parthen', 'Azhagiya Theeye', 'Ennavale Adi Ennavale', 'Mannipaaya']
# Most Played Song per Genre: {'Melody': 'Endhira Logathu Sundariye'}
#
# User 12:
# Recommended Songs: ['Uyire Uyire', 'Endhira Logathu Sundariye', 'Neethane Neethane', 'Mannipaaya', 'Pachai Nirame']
# Most Played Song per Genre: {'Melody': 'Azhagiya Theeye'}
#
# User 13:
# Recommended Songs: ['Endhira Logathu Sundariye', 'Munbe Vaa', 'Mannipaaya', 'Uyire Uyire', 'Ninaithu Ninaithu Parthen']
# Most Played Song per Genre: {'Melody': 'Neethane Neethane'}
#
# User 14:
# Recommended Songs: ['Munbe Vaa', 'Oru Deivam Thantha Poove', 'Ninaithu Ninaithu Parthen', 'Ithu Kaadhal Kaadhal Kaatchi', 'Kannamoochi Yenada']
# Most Played Song per Genre: {'Pop': 'Munbe Vaa'}
#
# User 15:
# Recommended Songs: ['Uyire Uyire', 'Munbe Vaa', 'Ithu Kaadhal Kaadhal Kaatchi', 'Ninaithu Ninaithu Parthen', 'Kannamoochi Yenada']
# Most Played Song per Genre: {'Pop': 'Kannamoochi Yenada'}
#
# User 16:
# Recommended Songs: ['Poongatrile Un Swasathai', 'Snehithane Snehithane', 'Pachai Nirame', 'Neethane Neethane', 'Munbe Vaa']
# Most Played Song per Genre: {'Sad': 'Snehithane Snehithane'}
#
# User 17:
# Recommended Songs: ['Kannukkul Nilavu', 'Uyire Uyire', 'Ennavale Adi Ennavale', 'Munbe Vaa', 'Pachai Nirame']
# Most Played Song per Genre: {'Melody': 'Pachai Nirame'}
#
# User 18:
# Recommended Songs: ['Ninaithu Ninaithu Parthen', 'Pachai Nirame', 'Mannipaaya', 'Kannukkul Nilavu', 'Munbe Vaa']
# Most Played Song per Genre: {'Melody': 'Munbe Vaa'}
#
# User 19:
# Recommended Songs: ['Oru Deivam Thantha Poove', 'Ithu Kaadhal Kaadhal Kaatchi', 'Uyire Uyire', 'Kannamoochi Yenada', 'Munbe Vaa']
# Most Played Song per Genre: {'Pop': 'Ninaithu Ninaithu Parthen'}
#
# User 20:
# Recommended Songs: ['Kannukkul Nilavu', 'Ithu Kaadhal Kaadhal Kaatchi', 'Endhira Logathu Sundariye']
# Most Played Song per Genre: {'R&B': 'Endhira Logathu Sundariye'}
#
# User 21:
# Recommended Songs: ['Ninaithu Ninaithu Parthen', 'Azhagiya Theeye', 'Endhira Logathu Sundariye', 'Munbe Vaa', 'Neethane Neethane']
# Most Played Song per Genre: {'Melody': 'Ninaithu Ninaithu Parthen'}
#
# User 22:
# Recommended Songs: ['Thendral Vanthu Theendum Pothu', 'Munbe Vaa', 'Kannukkul Nilavu', 'Kadhal Anukkal', 'Endhira Logathu Sundariye']
# Most Played Song per Genre: {'Folk': 'Kadhal Anukkal'}
#
# User 23:
# Recommended Songs: ['Endhira Logathu Sundariye', 'Kadhal Anukkal', 'Kannukkul Nilavu', 'Thendral Vanthu Theendum Pothu', 'Kannamoochi Yenada']
# Most Played Song per Genre: {'Folk': 'Kannamoochi Yenada'}
#
# User 24:
# Recommended Songs: ['Pachai Nirame', 'Poongatrile Un Swasathai', 'Munbe Vaa', 'Snehithane Snehithane', 'Neethane Neethane']
# Most Played Song per Genre: {'Sad': 'Neethane Neethane'}
#
# User 25:
# Recommended Songs: ['Kannamoochi Yenada', 'Oru Deivam Thantha Poove', 'Uyire Uyire', 'Munbe Vaa', 'Ithu Kaadhal Kaadhal Kaatchi']
# Most Played Song per Genre: {'Pop': 'Ithu Kaadhal Kaadhal Kaatchi'}
#
# User 26:
# Recommended Songs: ['Ennai Thalatta Varuvala', 'Azhagiya Theeye', 'Pachai Nirame', 'Kadhal Anukkal']
# Most Played Song per Genre: {'Rock': 'Pachai Nirame'}
#
# User 27:
# Recommended Songs: ['Kadhal Anukkal', 'Enna Solla Pogirai', 'Anbe Anbe Kollathey', 'Poongatrile Un Swasathai', 'Ninaithu Ninaithu Parthen']
# Most Played Song per Genre: {'Other': 'Ninaithu Ninaithu Parthen'}
#
# User 28:
# Recommended Songs: ['Kannukkul Nilavu', 'Munbe Vaa', 'Mannipaaya', 'Uyire Uyire', 'Neethane Neethane']
# Most Played Song per Genre: {'Melody': 'Munbe Vaa'}
#
# User 29:
# Recommended Songs: ['Kadhal Anukkal', 'Enna Solla Pogirai', 'Ninaithu Ninaithu Parthen', 'Anbe Anbe Kollathey', 'Poongatrile Un Swasathai']
# Most Played Song per Genre: {'Other': 'Kadhal Anukkal'}
#
# User 30:
# Recommended Songs: ['Ithu Kaadhal Kaadhal Kaatchi', 'Kannamoochi Yenada', 'Uyire Uyire', 'Oru Deivam Thantha Poove', 'Ninaithu Ninaithu Parthen']
# Most Played Song per Genre: {'Pop': 'Oru Deivam Thantha Poove'}
#
# User 31:
# Recommended Songs: ['Azhagiya Theeye', 'Pachai Nirame', 'Kadhal Anukkal', 'Ennai Thalatta Varuvala']
# Most Played Song per Genre: {'Rock': 'Azhagiya Theeye'}
#
# User 32:
# Recommended Songs: ['Neethane Neethane', 'Munbe Vaa', 'Mannipaaya', 'Azhagiya Theeye', 'Uyire Uyire']
# Most Played Song per Genre: {'Melody': 'Kannukkul Nilavu'}
#
# User 33:
# Recommended Songs: ['Munbe Vaa', 'Neethane Neethane', 'Poongatrile Un Swasathai', 'Pachai Nirame', 'Snehithane Snehithane']
# Most Played Song per Genre: {'Sad': 'Snehithane Snehithane'}
#
# User 34:
# Recommended Songs: ['Ninaithu Ninaithu Parthen', 'Neethane Neethane', 'Kannamoochi Yenada', 'Poongatrile Un Swasathai', 'Kadhal Anukkal']
# Most Played Song per Genre: {'Other': 'Poongatrile Un Swasathai'}
#
# User 35:
# Recommended Songs: ['Munbe Vaa', 'Pachai Nirame', 'Neethane Neethane', 'Snehithane Snehithane', 'Poongatrile Un Swasathai']
# Most Played Song per Genre: {'Sad': 'Poongatrile Un Swasathai'}
#
# User 36:
# Recommended Songs: ['Endhira Logathu Sundariye', 'Kannamoochi Yenada', 'Munbe Vaa', 'Kannukkul Nilavu', 'Thendral Vanthu Theendum Pothu']
# Most Played Song per Genre: {'Folk': 'Endhira Logathu Sundariye'}
#
# User 37:
# Recommended Songs: ['Thendral Vanthu Theendum Pothu', 'Endhira Logathu Sundariye', 'Kadhal Anukkal', 'Kannamoochi Yenada', 'Munbe Vaa']
# Most Played Song per Genre: {'Folk': 'Kannukkul Nilavu'}
#
# User 38:
# Recommended Songs: ['Ennai Thalatta Varuvala', 'Kadhal Anukkal', 'Pachai Nirame', 'Azhagiya Theeye']
# Most Played Song per Genre: {'Rock': 'Ennai Thalatta Varuvala'}
#
# User 39:
# Recommended Songs: ['Neethane Neethane', 'Kannukkul Nilavu', 'Ninaithu Ninaithu Parthen', 'Mannipaaya', 'Pachai Nirame']
# Most Played Song per Genre: {'Melody': 'Azhagiya Theeye'}
#
# User 40:
# Recommended Songs: ['Thendral Vanthu Theendum Pothu', 'Kannamoochi Yenada', 'Neethane Neethane', 'Enna Solla Pogirai', 'Kadhal Anukkal']
# Most Played Song per Genre: {'Other': 'Neethane Neethane'}
#
# User 41:
# Recommended Songs: ['Neethane Neethane', 'Thendral Vanthu Theendum Pothu', 'Enna Solla Pogirai', 'Kannamoochi Yenada', 'Kadhal Anukkal']
# Most Played Song per Genre: {'Other': 'Anbe Anbe Kollathey'}
#
# User 42:
# Recommended Songs: ['Ithu Kaadhal Kaadhal Kaatchi', 'Endhira Logathu Sundariye', 'Kannukkul Nilavu']
# Most Played Song per Genre: {'R&B': 'Ithu Kaadhal Kaadhal Kaatchi'}
#
# User 43:
# Recommended Songs: ['Neethane Neethane', 'Pachai Nirame', 'Munbe Vaa', 'Poongatrile Un Swasathai', 'Snehithane Snehithane']
# Most Played Song per Genre: {'Sad': 'Munbe Vaa'}
#
# User 44:
# Recommended Songs: ['Neethane Neethane', 'Enna Solla Pogirai', 'Anbe Anbe Kollathey', 'Ninaithu Ninaithu Parthen', 'Poongatrile Un Swasathai']
# Most Played Song per Genre: {'Other': 'Anbe Anbe Kollathey'}
#
# User 45:
# Recommended Songs: ['Anbe Anbe Kollathey', 'Poongatrile Un Swasathai', 'Kannamoochi Yenada', 'Ninaithu Ninaithu Parthen', 'Kadhal Anukkal']
# Most Played Song per Genre: {'Other': 'Thendral Vanthu Theendum Pothu'}
#
# User 46:
# Recommended Songs: ['Poongatrile Un Swasathai', 'Kadhal Anukkal', 'Kannamoochi Yenada', 'Neethane Neethane', 'Ninaithu Ninaithu Parthen']
# Most Played Song per Genre: {'Other': 'Enna Solla Pogirai'}
#
# User 47:
# Recommended Songs: ['Kannamoochi Yenada', 'Endhira Logathu Sundariye', 'Thendral Vanthu Theendum Pothu', 'Kadhal Anukkal', 'Munbe Vaa']
# Most Played Song per Genre: {'Folk': 'Munbe Vaa'}
#
# User 48:
# Recommended Songs: ['Pachai Nirame', 'Azhagiya Theeye', 'Ennai Thalatta Varuvala', 'Kadhal Anukkal']
# Most Played Song per Genre: {'Rock': 'Kadhal Anukkal'}
#
# User 49:
# Recommended Songs: ['Ithu Kaadhal Kaadhal Kaatchi', 'Kannukkul Nilavu', 'Endhira Logathu Sundariye']
# Most Played Song per Genre: {'R&B': 'Kannukkul Nilavu'}
#
# User 50:
# Recommended Songs: ['Snehithane Snehithane', 'Poongatrile Un Swasathai', 'Pachai Nirame', 'Neethane Neethane', 'Munbe Vaa']
# Most Played Song per Genre: {'Sad': 'Pachai Nirame'}
